# %%
import GravityMachineTrack
import imp
import pandas as pd
import numpy as np
import os
imp.reload(GravityMachineTrack)
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

rc('font', family='sans-serif') 
rc('font', serif='Helvetica') 
rc('text', usetex='false') 
rcParams.update({'font.size': 16})

trackFile = 'F:/Monterey_2019/2019_08_15/Akshiwo_sp/dino9/track000.csv'

track = GravityMachineTrack.gravMachineTrack(trackFile = trackFile, Tmin=0, Tmax = 80, findDims = True)

track.computeVelocityOrientation()

orientation_theta_smoothed = track.smoothSignal(track.orientation_theta,2)
# Out:
# Path : F:/Monterey_2019/2019_08_15/Akshiwo_sp/dino9
# images
# PIVres
# PIVres
# dino9
# ['Time', 'Xobj', 'Yobj', 'Xobj_image', 'Zobj', 'ThetaWheel', 'ZobjWheel', 'Manual Tracking', 'Image name', 'Focus Measure', 'Liquid Lens Phase', 'Liquid Lens Freq', 'Liquid Lens Ampl', 'Liquid Lens maxGain', 'Y FM maximum', 'Light Experiment', 'LED_Intensity', 'Lens position']
# 0
# 4259
# Track duration : 79.99175977706909
# Sampling frequency: 53.23048288807147
# Image height, Image width: 405, 720
# Pixel per mm : 314.0
# Pixels per mm: 314.0
# Color thresholds available!
#  Loading file F:/Monterey_2019/2019_08_15/Akshiwo_sp\colorThresholds.pkl ...
# Color thresholds for segmentation:
#  LOW: (0, 0, 46), HIGH : (255, 255, 255)
# F:/Monterey_2019/2019_08_15/Akshiwo_sp/dino9
# Loading organism size from memory ...
# **************************************************
# Organism dimension 0.0690475008506043 mm
# Organism Major dimension 0.0690475008506043 mm
# ...

# %%
print(track.orientation_theta)
# Out:
# [109.74493614 111.29828023 112.95220597 ... 104.29008374 106.18350049
#  107.9876557 ]

# %%
# Plot the Orientation time series

plt.figure()

plt.scatter(track.T, track.orientation_theta, 10, marker = 'o',color = 'g', alpha = 0.3)
plt.plot(track.T, orientation_theta_smoothed, color = 'k', linestyle = '-')
plt.xlabel('Time (s)')
plt.ylabel('Orientation to vertical (degrees)')
plt.ylim([0, 180])
plt.yticks([0,30, 60, 90, 120, 150, 180])

saveFile = 'Akashiwo_OrientationDecorrelation_track9'
plt.savefig(saveFile + '.png', dpi = 150)
plt.savefig(saveFile + '.svg', dpi = 150)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.506218015851">
